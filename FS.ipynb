# %% [markdown]
# **Introduction**
#
# In this project, we aim to develop an intelligent system capable of identifying and classifying four types of
#  fruits — apple, lemon, mandarin, and orange — using machine learning techniques. The system is designed to detect each fruit based on its visual characteristics and automatically sort it into the correct category basket.
#
# To implement the classification model, we used the K-Nearest Neighbors (KNN) algorithm, a widely-used and intuitive supervised learning method. KNN classifies new inputs based on the majority class among their closest neighbors in the feature space, making it highly effective for tasks where clear boundaries exist between categories.
#
# By combining data preprocessing, feature extraction, and model training, this project demonstrates a practical application of machine learning in real-world classification tasks, particularly in domains such as agriculture, food industry automation, and robotic systems.

# %% [markdown]
# **Libraries used**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import scatter_matrix
from matplotlib import cm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# **Reading the dataset**

# %%
fruits=pd.read_table("fruit.txt")

# %% [markdown]
# **Exploratory Data Analysis (EDA)**

# %%
fruits.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
print(fruits.groupby("fruit_name").size())
# Out:
# fruit_name
# apple       19
# lemon       16
# mandarin     5
# orange      19
# dtype: int64

# %% [markdown]
# **Droping and Continue EDA**
#
# Dropping unused columns from the dataset and setting x and y values and Data Mining

# %%
x=fruits[["mass","width","height","color_score"]]
y=fruits['fruit_label']
cmap=cm.get_cmap('gnuplot')
scatter=scatter_matrix(x,c=y,marker='o',s=40,hist_kwds={'bins':15},figsize=(9,9),cmap=cmap)
plt.suptitle("scatter_matrix for each input variable")
plt.savefig("fruits_scatter_matrix")
# Out:
# C:\Users\Puria\AppData\Local\Temp\ipykernel_4176\3729204259.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap=cm.get_cmap('gnuplot')

# %% [markdown]
# **Splitting the data into training and testing sets**

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# **Data Normalization**

# %%
scaler=MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %% [markdown]
# **Model**
#
# Building the model and training the model

# %%
Robot=KNeighborsClassifier()
Robot.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# **Prediction**
#
# Making predictions with the model

# %%
Robot.predict(X_test)
# Out:
# array([3, 3, 4, 3, 1, 1, 3, 4, 3, 1, 2, 1])

# %%
y_test
# Out:
# 26    3
# 35    3
# 43    4
# 28    3
# 11    1
# 2     1
# 34    3
# 46    4
# 40    3
# 22    1
# 4     2
# 10    1
# Name: fruit_label, dtype: int64

# %% [markdown]
# **Model accuracy percentage**

# %%
Robot.score(X_test,y_test)
# Out:
# 1.0

# %% [markdown]
# **Conclusion**
#
# In this project, we successfully developed a fruit classification system capable of distinguishing between
#  apple, lemon, mandarin, and orange using the K-Nearest Neighbors (KNN) algorithm. The pipeline included data preprocessing, feature extraction, and model training, resulting in reliable classification performance.
#
# The choice of KNN proved effective due to its simplicity, interpretability, and solid performance in multi-class classification problems. The system demonstrates how basic yet well-structured machine learning approaches can be applied to real-world tasks such as automated fruit sorting and object recognition in robotic systems.
#
# Overall, the results highlight that with proper feature selection and preprocessing, even straightforward algorithms can achieve high accuracy in practical applications — paving the way for further development in smart agriculture and food industry automation.
